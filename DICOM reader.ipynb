# %%
import pydicom

def read_dicom_file(file_path):
    """
    Reads a DICOM file and returns the dataset.

    :param file_path: Path to the DICOM file.
    :return: pydicom Dataset object.
    """
    try:
        dataset = pydicom.dcmread(file_path)
        return dataset
    except Exception as e:
        print(f"Error reading DICOM file: {e}")
        return None

# %%
dicom_file_path = r"C:\Users\david\OneDrive\Documents\GitHub\General\test.dcm"
read_dicom_file(dicom_file_path)
# Out:
# Dataset.file_meta -------------------------------
# (0002,0000) File Meta Information Group Length  UL: 190
# (0002,0001) File Meta Information Version       OB: b'\x00\x01'
# (0002,0002) Media Storage SOP Class UID         UI: CT Image Storage
# (0002,0003) Media Storage SOP Instance UID      UI: 2.16.840.1.114362.1.12177026.23360333229.706746605.172.17
# (0002,0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002,0012) Implementation Class UID            UI: 2.16.840.1.114362.1
# (0002,0013) Implementation Version Name         SH: 'MIM728MB1102'
# -------------------------------------------------
# (0008,0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008,0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL']
# (0008,0012) Instance Creation Date              DA: '20250422'
# (0008,0013) Instance Creation Time              TM: '112042'
# (0008,0016) SOP Class UID                       UI: CT Image Storage
# ...
